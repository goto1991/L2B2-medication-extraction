# %%
import numpy as np
import re
import random
import itertools
import datetime

import tensorflow as tf
import sklearn as sk
import colorama as col

from gensim.models import Word2Vec

import Functions as fn
from DS import DS
from Set import pool
from Iterator import Iterator
from FFModel import FF_Model
# Out:
# C:\Users\Luka\Anaconda3\envs\tensorflow\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# # Data Loading

# %%
Dataset = pool()
Dataset.load_texts('raw_texts')
Dataset.load_labels('raw_labels')
# Out:
# Raw Text Load Complete
# Raw Labels Load Complete

# %%
target_dict = fn.load_labels('labels')
# Out:
# Label Load Complete

# %% [markdown]
# # Embedding Generation

# %%
#Dataset.process_for_embedding()
#sentences = Dataset.get_sentences()
#fn.write_sentences('sentences')
sentences = fn.load_sentences('sentences')

#model = Word2Vec(sentences, min_count=1, size=100)
#model.save('W2V')
model = Word2Vec.load('W2V')

vocab = model.wv.vocab.keys()
# Out:
# Sentence Load Complete

# %% [markdown]
# # FFNN Testing

# %%
train_cases = pool((Dataset.get_DS(stage='test', labelled='yes')).data[:-25])
validation_cases = pool(Dataset.get_DS(stage='test', labelled='yes').data[-25:])
test_cases = Dataset.get_DS(stage='train', labelled='yes')

train_cases.process_for_testing()
validation_cases.process_for_testing()
test_cases.process_for_testing()

# %%
sets = {}
sets['train_set'], sets['train_labels'], _ = train_cases.get_ff_sets(model)
sets['validation_set'], sets['validation_labels'], _ = validation_cases.get_ff_sets(model)
sets['test_set'], sets['test_labels'], sets['test_words'] = test_cases.get_ff_sets(model)

# %%
print('Ratio: med: {:.2f}% non-med: {:.2f}%'.format(*(np.array(sets['train_labels']).sum(0)/ len(sets['train_labels']))))
fn.saturate_training_set_training(sets['train_set'], sets['train_labels'], 0.1)
print('Ratio: med: {:.2f}% non-med: {:.2f}%'.format(*(np.array(sets['train_labels']).sum(0)/ len(sets['train_labels']))))
# Out:
# Ratio: med: 0.05% non-med: 0.95%
# Ratio: med: 0.13% non-med: 0.87%

# %%
NN = FF_Model(layers=[50])
NN.build_graph()
_,_,_,_ = NN.train(sets, epochs=10, batch=50, show_plot=True, show_progress=True)
# Out:
# Progress: 100%
# FInal Values: TrAcc: 0.9691, ValAcc: 0.9856, ValF1: 0.8215
# Test F1-Score: 0.8560

# %%
res = NN.predict(sets['test_set'])
tru = np.argmax(sets['test_labels'], 1)

# %%
_ = fn.token_perf(res, tru)
# Out:
# TP	TN	FP	FN
# 434	10581	64	82
#
# Precision: 0.8715
# Recall: 0.8411
# F1-Score: 0.8560

# %%
baseline = [0 if word in target_dict['medications'] else 1 for word in sets['test_words']]
sk.metrics.f1_score(tru, baseline, pos_label=0, average='binary')

# %%
fn.category_words(sets['test_words'], res, tru, 0, 1)
# Out:
# codeine, rose-walt, tablets, sodium, potassium, chloride, magnesium, boluses, sodium, potassium, chloride, magnesium, nasal, inhibitor, tylenol, insulin, hep, micro, sedation, antibiotics, m/w/f, therapeutic, ischemia-mr, grana, aspirin, insulin, therapeutic, m/w/f, caffeine, morphine, sodium, potassium, chloride, calcium, magnesium, loading, iron, therapeutic, monday-wednesday-friday, flagyl, monday-wednesday-friday, monday-wednesday-friday, medication, rx, monday-wednesday-friday, monday-wednesday-friday, medication, penicillin, hcl, huyett, hydrate, riss, quinine, aspirin, <num>.<num>-<num>, aspirin, motrin, spray, sodium, aspirin, sprays, aspirin, ppi, iss

# %%
fn.colour_text(sets['test_words'], res, tru)
# Out:
# record #<num> <num> | tmh | <num> | | <num> | <num>/<num>/<num> <num>:<num>:<num> am | discharge summary | signed | dis | admission date <num>/<num>/<num> report status signed discharge date <num>/<num>/<num> history ms pizzo is a <num>-year-old woman with peripheral vascular disease who recently underwent revision of her left superior femoral artery anterior tibial bypass graft , who now presents with a cool , ischemic left foot mrs denman is a <num>-year-old , insulin-dependent diabetic with a long history of peripheral vascular disease as well as multiple surgical procedures she underwent a right transmetatarsal amputation in <num> and subsequently underwent a right femorla distal saphenous vein bypass graft in <num> which was later revised in <num>. she seems to be doing well with the left side until july of this year , at which time she underwent a left superficial femoral artery to anterior tibial artery bypass using non-reversed basilic vein harvested from the right arm she , however , had a large great toe ulcer , possibly attributed to hammertoe , which subsequently underwent a left great toe amputation performed on the <num> of october . after this time , she was discharged to the nut hospital in amore pu , where she was making progress in physical therapy and rehabilitation on the day prior to admission , she was exercising with <num> pound weights on her legs with the physical therapist when she described a cool sensation in her foot she reported that her foot had been blue , and there were no dopplerable pulses color later returned the absence of pulses persisted over the course of the night , after which point she was referred back to largrine medical center for evaluation she denies any significant pain or any other complications past medical history remarkable for history of insulin-dependent diabetes , history of coronary artery disease , history of hypertension , cataracts , mrsa from her toe wound on the <num> of september past surgical history notable for the above , as well as debridements of her toe amputation wound site admission medications COLACE <num> mg bid , INSULIN LENTE <num> units subcu q pm supplemented by sliding scale regular INSULIN scale , ISORDIL <num> mg tid , ZESTRIL <num> mg q d , LOPRESSOR <num> mg bid , AXID <num> mg bid , OFLOXACIN <num> mg po q <num> , ECOTRIN <num> mg q d , VANCOMYCIN <num> mg q <num>. she reports an allergy to CODEINE and iodine admission examination remarkable for the following findings she was afebrile , heart rate <num> , blood pressure <num>/<num>. her right lower extremity was characterized by a well-healed transmetatarsal amputation site the foot was warm and pink the left side , however , was cool in comparison , although remained pink with adequate capillary refill both femoral pulses were easily palpable , as well as dorsal pedal pulse on the right her right posterior tibial pulse was additionally biphasic by doppler on the left , she had a biphasic doppler graft pulse and dorsopedal , although she had no identifiable posterior tibial pulse the remainder of the examination was unremarkable admission labs were likewise unremarkable hospital course mrs bulger was admitted and placed on intravenous HEPARIN until the following morning , at which time she proceeded to the angiography suite she was found to have two <num>% stenosis in a long segment of the left sfa and the left distal sfa and anterior tibial vein graft was completely thrombosed she was successfully treated with stent placement and received HEPARIN and UROKINASE in the intensive care unit overnight with a turn-over pulses of the left leg doppler the following day , her stents were removed during the remainder of the hospital course , her left foot remained pink and warm her wound had an infection of exposed bone , but otherwise appeared to be granulating well although left transmetatarsal amputation being considered , it was felt that she had a good chance of healing the wound appropriately she h ...

# %% [raw]
# no_brac = {}
# no_brac['words'] = []
# no_brac['res'] = []
# no_brac['tru'] = []
# for i in range(len(res)):
#     if not (sets['test_words'][i] == ')' or sets['test_words'][i] == '('):
#         no_brac['words'].append(sets['test_words'][i])
#         no_brac['res'].append(res[i])
#         no_brac['tru'].append(tru[i])

# %% [raw]
# _ = fn.token_perf(res=no_brac['res'], tru=no_brac['tru'])

# %% [raw]
# fn.category_words(no_brac['words'], no_brac['res'], no_brac['tru'], 0, 1)

# %% [raw]
# fn.colour_text(no_brac['words'], no_brac['res'], no_brac['tru'])

# %%
testers = Dataset.get_DS(stage='train', labelled='yes')
_ = fn.phrase_perf(NN, testers, model, case_info=True, show_phrases=True)
# Out:
# Name:  0101
# Challenge:  2009 Medication Challenge
# Train or Test Set:  train
# Labelled:  yes
# Labeling Type:  train
#
#
# Result Medications:
# antibiotics, lopressor, colace, insulin nph, rose-walt, percocet, isordil, codeine, tablets, zestril, insulin lente, axid, ecotrin, insulin, vancomycin, heparin, urokinase, ofloxacin, coumadin
#
# True Medications:
# antibiotics, lopressor, colace, insulin nph, percocet, isordil, heparin, zestril, axid, ecotrin, vancomycin, insulin, urokinase, insulin lente, ofloxacin, coumadin
#
# Name:  0102
# Challenge:  2009 Medication Challenge
# Train or Test Set:  train
# Labelled:  yes
# Labeling Type:  train
#
#
# Result Medications:
# potassium, metformin, chloride, atenolol, sodium, motrin, magnesium, lantus, toprol-xl, potassium chloride slow release, lasix, insulin, novolog, nasal, precedex, aspirin, beta-blocker, humalog insulin, ciprofloxacin, epinephrine, boluses, baby aspirin
#
# True Medications:
# aspirin, toprol-xl, potassium chloride slow release, beta-blocker, metformin, humalog insulin, motrin, nasal cannula, lasix, atenolol, ciprofloxacin, insulin, baby aspirin, lantus, novolog, precedex, epinephrine
#
# Name:  0105
# Challenge:  2009 Medication Challenge
# Train or Test Set:  train
# Labelled:  yes
# Labeling Type:  train
#
#
# Result Medications:
# atenolol, neurontin, heparin, inhibitor, ace inhibitor, celexa, plavix, zocor, lopressor, percocet, packed, lipitor, glucophage, nasal, aspirin, beta-blocker, lovenox, zestril, captopril, nitroglycerin, klonopin, plasma, tylenol
#
# True Medications:
# protamine, neurontin, heparin, atenolol, ace inhibitor, celexa, plavix, zocor, lopressor, percocet, fresh frozen plasma, lipitor, glucophage, packed red blood cells, aspirin, beta-blocker, lovenox, zestril, captopril, nitroglycerin, klonopin, tylenol
#
# Name:  0106
# Challenge:  2009 Medication Challenge
# Train or Test Set:  train
# Labelled:  yes
# Labeling Type:  train
#
#
# Result Medications:
# colace, neurontin, heparin, therapeutic, vancomycin, b-blocker, lantus, flagyl, folate, augmentin, m/w/f, lisinopril, lopressor, ativan, levofloxacin, lipitor, protonix, insulin, ketamine, antibiotics, micro, renagel, aspirin, gemfibrozil, requip, fentanyl pca, oxycontin, phoslo, coumadin, ischemia-mr grana, hep, unasyn, lyrica, nephrocaps, aspart, medication, oxycodone, sedation
#
# True Medications:
# colace, neurontin, heparin, vancomycin, b-blocker, lantus, flagyl, folate, augmentin, pain medication, lopressor, ativan, lisinopril, levofloxacin, lipitor, protonix, ketamine, antibiotics, pain medications, renagel, gemfibrozil, requip, fentanyl pca, oxycontin, phoslo, coumadin, unasyn, lyrica, nephrocaps, aspart, oxycodone
#
# Name:  0107
# Challenge:  2009 Medication Challenge
# Train or Test Set:  train
# Labelled:  yes
# Labeling Type:  train
#
#
# Result Medications:
# magnesium oxide, iron, potassium, chloride, sodium, heparin, therapeutic, magnesium, isosorbide, amiodarone, lopressor, morphine, glipizide, calcium, lasix, levothyroxine sodium, clonazepam, caffeine, captopril, nitroglycerin, coumadin, klonopin, levothyroxine, simvastatin, digoxin, troglipazone, loading, ptu
#
# True Medications:
# magnesium oxide, isosorbide, clonazepam, lopressor, simvastatin, digoxin, nitroglycerin <num>/<num> ( <num>.<num> mg ), levothyroxine sodium, mononitrate-sr, lasix, heparin, glipizide, captopril, troglipazone, coumadin, klonopin, amiodarone, levothyroxine, ptu
#
# Name:  0108
# Challenge:  2009 Medication Challenge
# Train or Test Set:  train
# Labelled:  yes
# Labeling Type:  train
#
#
# Result Medications:
# advair diskus, sevelamer, thiamine, norvasc, albuterol butt paste, flagyl, lantus, loperamide, folate, haldol, lisinopril, ativan, insulin, labetalol, antibiotics, cefpodoxime, phoslo, monday-wednesday-friday, gabapentin, albuterol inhaler, nephrocaps, tylenol, aspart, depakote, nexium, ceftriaxone, medication rx
#
# True Medications:
# sevelamer, thiamine, advair diskus <num>/<num>, norvasc, albuterol butt paste, flagyl, lantus, loperamide, folate, haldol, lisinopril, ativan, insulin, labetalol, antibiotics, cefpodoxime, phoslo, gabapentin, albuterol inhaler, nephrocaps, tylenol, aspart, depakote, nexium, ceftriaxone
#
# Name:  0109
# Challenge:  2009 Medication Challenge
# Train or Test Set:  train
# Labelled:  yes
# Labeling Type:  train
#
#
# Result Medications:
# hydrochlorothiazide, lisinopril, aspirin, simvastatin, metformin, nph, atenolol, lasix, medication, insulin, nifedipine extended release, penicillin
#
# True Medications:
# hydrochlorothiazide, aspirin, lisinopril, simvastatin, metformin, nph, atenolol, lasix, insulin, nifedipine extended release
#
# Name:  0110
# Challenge:  2009 Medication Challenge
# Train or Test Set:  train
# Labelled:  yes
# Labeling Type:  train
#
#
# Result Medications:
# riss, sarna, warfarin, glyburide, huyett, kcl immediate release, lisinopril, powder, warfarin sodium, esomeprazole, antibiotics, aspirin, ciprofloxacin hcl, vanc, hydrate, acetylsalicylic acid, ciprofloxacin, levo, coumadin, linezolid, unasyn, simvastatin, miconazole nitrate, nexium, potassium chloride, cipro
#
# True Medications:
# antibiotics, lisinopril, simvastatin, aspirin, ada, sarna, potassium chloride, cipro, warfarin, acetylsalicylic acid, ciprofloxacin, vanc, coumadin ( warfarin sodium ), levo, nexium ( esomeprazole ), miconazole nitrate <num>% powder, coumadin, glyburide, linezolid, unasyn, kcl immediate release
#
# Name:  0111
# Challenge:  2009 Medication Challenge
# Train or Test Set:  train
# Labelled:  yes
# Labeling Type:  train
#
#
# Result Medications:
# tears naturale, hydroxychloroquine, colace, isordil, norvasc, neurontin, docusate sodium, quinine, therapeutic multivi.., plaquenil sulfate, amiodarone, lisinopril, multivitamin therapeutic, micronase, glipizide, lasix, esomeprazole, artificial tears, furosemide, trazodone, aspirin, nitroglycerin, coumadin, gabapentin, amlodipine, isosorbide dinitrate, nexium, potassium chloride, <num>.<num>-<num>
#
# True Medications:
# trazodone, lisinopril, lasix ( furosemide ), norvasc ( amlodipine ), micronase, nitroglycerin <num>/<num> ( <num>.<num> mg ), glipizide, lasix, potassium chloride, nexium ( esomeprazole ), colace ( docusate sodium ), plaquenil sulfate ( hydroxychloroquine ), multivitamin therapeutic ( therapeutic multivi.. ), coumadin, neurontin ( gabapentin ), amiodarone, tears naturale ( artificial tears ), isordil ( isosorbide dinitrate )
#
# Name:  0121
# Challenge:  2009 Medication Challenge
# Train or Test Set:  train
# Labelled:  yes
# Labeling Type:  train
#
#
# Result Medications:
# magnesium oxide, amox, advair diskus, albuterol, metformin, rhinocort aqua, effexor, motrin, kcl slow release, sodium, sprays, advair, zocor, singulair, verapamil, loratadine, montelukast, lasix, ambien, esomeprazole, antibiotics, zolpidem tartrate, iss, effexor xr, atrovent, keflex, fluticasone propionate/..., furosemide, aspirin, rhinocort, budesonide nasal inhaler, ppi, simvastatin, loratidine, albuterol inhaler, ibuprofen, venlafaxine extended release, potassium chloride slow rel, motrin atrovent hfa inhaler, potassium chloride, spray, cephalexin, nexium, kcl, oxycodone, release, ipratropium inhaler
#
# True Medications:
# magnesium oxide, amox, metformin <num>, albuterol, metformin, effexor, motrin, motrin ( ibuprofen ), zocor, singulair, singulair ( montelukast ), atrovent hfa inhaler ( ipratropium inhaler ), verapamil, potassium chloride slow rel ( kcl slow release ), loratadine, lasix, ambien, ambien ( zolpidem tartrate ), keflex ( cephalexin ), antibiotics, rhinocort aqua ( budesonide nasal inhaler ), mgoxide, patanol, atrovent, keflex, rhinocort, lasix ( furosemide ), nexium ( esomeprazole ), advair <num>/<num>, loratidine, albuterol inhaler, verapamil sustained release, nexium, potassium chloride, kcl, effexor xr ( venlafaxine extended release ), oxycodone, zocor ( simvastatin ), advair diskus <num>/<num> ( fluticasone propionate/... )
#
# TP	FP	FN
# 178	93	40
#
# Precision: 0.6568
# Recall: 0.8165
# F1-Score: 0.7280

# %% [markdown]
# # HyperParameter Scan

# %%
emb_num = 1
NN_num = 1
emb_sizes = [30, 50, 100]
target_saturations = [0.05, 0.1, 0.3]
layers = [[30], [50], [100]]
dropouts = [0.3, 0.5, 0.8, 1.0]
learn_rates = [0.001, 0.01, 0.1]
epoch_nums = [10, 50, 100]
batch_sizes = [10, 50, 100]


model_num = emb_num * NN_num * len(emb_sizes) * len(layers) * len(dropouts) * \
            len(learn_rates) * len(epoch_nums) * len(batch_sizes) * len(target_saturations)
target = target_dict['medications']
report_percentage = 10

print(model_num)

# %%
labelled_cases = Dataset.get_DS(labelled='yes')
labelled_cases.process_for_testing()

# %%
iterations = [emb_sizes, target_saturations, layers, dropouts, learn_rates, epoch_nums, batch_sizes]

# %%
n = 0
parameters = []
results = []
timestamp = re.sub(r':', '-', str(datetime.datetime.now()).split('.')[0])

with open('tests/Model2/' + timestamp, 'w+') as f:
    print('EmbSz:\tSat:\tLay:\tDrop:\tLeRa:\tEpochs:\tBatSz:\tF1:')
    f.write('EmbSz:\tSat:\tLay:\tDrop:\tLeRa:\tEpochs:\tBatSz:\tF1:\n')
    for par in itertools.product(*iterations):
        best = 0
        parameters.append(par)
        for i in range(emb_num):
            model = Word2Vec(sentences, min_count=1, size=par[0])
            sets = fn.get_ff_traintest(labelled_cases, model)
            fn.saturate_training_set_labels(sets, model, target, par[1])
            for j in range(NN_num):
                n += 1
                print('Model Number: {}/{}'.format(n, model_num), end='\r')
                NN = FF_Model(input_size=par[0], layers=par[2], dropout=par[3], learn_rate=par[4])
                NN.build_graph()
                _, _, _, score = NN.train(sets, epochs=par[5], batch=par[6], report_percentage=report_percentage)
                best = max(best, score)
        results.append(best)
        print('{}\t{}\t{}\t{}\t{}\t{}\t{}\t{:.4f}'.format(*parameters[-1], results[-1]))
        f.write('{}\t{}\t{}\t{}\t{}\t{}\t{}\t{:.4f}\n'.format(*parameters[-1], results[-1]))

    print('Max Performance: {:.4f}'.format(max(results)))  
    f.write('Max Performance: {:.4f}\n'.format(max(results)))
